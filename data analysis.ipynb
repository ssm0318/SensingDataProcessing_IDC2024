# %%
import pandas as pd

# %%
df_notifications = pd.read_csv('./notifications_processed.csv', index_col=0)
df_usage_stats = pd.read_csv('./usage_stats_processed.csv', index_col=0)

# %%
df_usage_events = pd.read_csv('./usage_events_processed.csv', index_col=0)

# %%
df_usage_events['datetime'] = pd.to_datetime(df_usage_events['datetime'])
df_notifications['datetime'] = pd.to_datetime(df_notifications['datetime'])

# %%
df_usage_events = df_usage_events[df_usage_events['eventType'] != 'NOT_DEFINED']

# %% [markdown]
# ### EDA

# %%
df_usage_events.columns
# Out:
# Index(['id', 'uuid', 'datetime', 'eventType', 'time', 'date', 'className',
#        'appName'],
#       dtype='object')

# %%
# REFERENCE: https://developer.android.com/reference/android/app/usage/UsageEvents.Event

# why is SCREEN_INTERACTIVE not present...?

df_usage_events['eventType'].unique()
# Out:
# array(['ACTIVITY_RESUMED', 'ACTIVITY_PAUSED', 'ACTIVITY_STOPPED',
#        'STANDBY_BUCKET_CHANGED', 'USER_INTERACTION',
#        'FOREGROUND_SERVICE_START', 'FOREGROUND_SERVICE_STOP',
#        'SHORTCUT_INVOCATION', 'NONE'], dtype=object)

# %%
usage = df_usage_events[df_usage_events['eventType'].isin(['ACTIVITY_RESUMED',
                                                           'ACTIVITY_PAUSED',
                                                           'ACTIVITY_STOPPED',
                                                           'FOREGROUND_SERVICE_START',
                                                           'USER_INTERACTION'])]

# %%
usage.to_csv('./activities_all.csv')

# %%
usage.groupby(['appName', 'eventType']).size().unstack(fill_value=0)
# Out:
# eventType  ACTIVITY_PAUSED  ACTIVITY_RESUMED  ACTIVITY_STOPPED  \
# appName
# AppMinder            11373             11659             11212
# Instagram           279196            279292            248832
# Snapchat             17516             17644             16831
# TikTok              126593            126610            124219
#
# eventType  FOREGROUND_SERVICE_START  USER_INTERACTION
# appName
# AppMinder                      2270               862
# Instagram                      3927             20529
# Snapchat                      44874              6256
# TikTok                          289               667

# %%
usage.groupby(['appName', 'eventType'])['className'].nunique().reset_index()
# Out:
#       appName                 eventType  className
# 0   AppMinder           ACTIVITY_PAUSED          3
# 1   AppMinder          ACTIVITY_RESUMED          2
# 2   AppMinder          ACTIVITY_STOPPED          2
# 3   AppMinder  FOREGROUND_SERVICE_START          2
# 4   AppMinder          USER_INTERACTION          0
# 5   Instagram           ACTIVITY_PAUSED         46
# 6   Instagram          ACTIVITY_RESUMED         46
# 7   Instagram          ACTIVITY_STOPPED         45
# 8   Instagram  FOREGROUND_SERVICE_START          3
# 9   Instagram          USER_INTERACTION          0
# 10   Snapchat           ACTIVITY_PAUSED          5
# 11   Snapchat          ACTIVITY_RESUMED          6
# 12   Snapchat          ACTIVITY_STOPPED          6
# 13   Snapchat  FOREGROUND_SERVICE_START          5
# 14   Snapchat          USER_INTERACTION          0
# 15     TikTok           ACTIVITY_PAUSED         75
# 16     TikTok          ACTIVITY_RESUMED         75
# 17     TikTok          ACTIVITY_STOPPED         79
# 18     TikTok  FOREGROUND_SERVICE_START          2
# 19     TikTok          USER_INTERACTION          0

# %%
unique_classnames = usage[usage['eventType'] == 'ACTIVITY_RESUMED'].groupby('appName')['className'].unique()
for appname, classnames in unique_classnames.items():
    print(f"App: {appname}")
    print(f"Unique classnames: {list(classnames)}\n")
# Out:
# App: AppMinder
# Unique classnames: ['com.example.drg2023.MainActivity', 'com.example.drg2023.DialogActivity']
#
# App: Instagram
# Unique classnames: ['com.instagram.modal.ModalActivity', 'com.instagram.mainactivity.MainActivity', 'com.instagram.urlhandlers.clips.ClipsUrlHandlerActivity', 'com.instagram.modal.TransparentModalActivity', 'com.instagram.mainactivity.LauncherActivity', 'com.facebook.browser.lite.BrowserLiteInMainProcessBottomSheetActivity', 'com.instagram.url.UrlHandlerLauncherActivity', 'com.instagram.url.UrlHandlerActivity', 'com.instagram.urlhandlers.media.MediaExternalUrlHandlerActivity', 'com.instagram.creation.activity.MediaCaptureActivity', 'com.instagram.business.promote.activity.PromoteActivity', 'com.instagram.urlhandlers.clipsaudio.ClipsAudioUrlHandlerActivity', 'com.instagram.nux.activity.BloksSignedOutFragmentActivity', 'com.instagram.rtc.activity.RtcCallIntentHandlerActivity', 'com.instagram.rtc.activity.RtcCallActivity', 'com.instagram.tagging.activity.TaggingActivity', 'com.instagram.nux.activity.SignedOutFragmentActivity', 'com.instagram.nux.impl.dynamicflow.onboarding.OnboardingActivity', 'com.instagram.creation.photo.crop.AvatarCropActivity', 'com.instagram.urlhandlers.professionaldashboardexternal.ProfessionalDashboardExternalUrlHandlerActivity', 'com.instagram.urlhandlers.directpollmessage.DirectPollMessageUrlHandlerActivity', 'com.instagram.direct.share.handler.DirectExternalMediaShareActivity', 'com.instagram.business.activity.BusinessConversionActivity', 'com.facebook.FacebookActivity', 'com.instagram.share.handleractivity.StoryShareHandlerActivity', 'com.instagram.direct.share.handler.DirectShareHandlerActivity', 'com.instagram.urlhandlers.interappidentityswitch.InterAppIdentitySwitchUrlHandlerActivity', 'com.instagram.urlhandlers.managesavedlogin.ManageSavedLoginUrlHandlerActivity', 'com.instagram.modal.TransparentBackgroundModalActivity', 'com.instagram.simplewebview.SimpleWebViewActivity', 'com.instagram.share.handleractivity.MultiStoryShareHandlerActivity', 'com.instagram.urlhandlers.directgroupinvite.DirectGroupInviteHandlerActivity', 'com.instagram.urlhandlers.viewprofile.ViewProfileUrlHandlerActivity', 'com.instagram.share.handleractivity.ShareHandlerActivity', 'com.instagram.share.handleractivity.CustomStoryShareHandlerActivity', 'com.instagram.urlhandlers.genericsurvey.GenericSurveyUrlHandlerActivity', 'com.instagram.urlhandlers.igme.IgMeExternalUrlHandlerActivity', 'com.instagram.urlhandlers.openinexternalbrowser.OpenInExternalBrowserUrlHandlerActivity', 'com.instagram.leadads.activity.LeadAdsActivity', 'com.instagram.challenge.activity.ChallengeActivity', 'com.instagram.urlhandlers.fundraiserexternal.FundraiserExternalUrlHandlerActivity', 'com.instagram.inappbrowser.actions.BrowserActionActivity', 'com.instagram.urlhandlers.consentaction.ConsentActionUrlHandlerActivity', 'com.instagram.urlhandlers.attribution.AttributionUrlHandlerActivity', 'com.instagram.fxcal.browser.FxChromeCustomTabsActivity', 'com.instagramdal.ModalActivity']
#
# App: Snapchat
# Unique classnames: ['com.snap.mushroom.MainActivity', 'com.snap.identity.loginsignup.ui.LoginSignupActivity', 'com.snap.identity.ui.legal.LegalAgreementActivity', 'com.snap.talk.lockscreen.LockScreenActivity', 'com.android.billingclient.api.ProxyBillingActivity', 'com.jakewharton.processphoenix.ProcessPhoenix']
#
# App: TikTok
# Unique classnames: ['com.ss.android.ugc.aweme.main.MainActivity', 'com.ss.android.ugc.aweme.search.pages.core.ui.activity.SearchResultActivity', 'com.ss.android.ugc.aweme.detail.ui.DetailActivity', 'com.ss.android.ugc.aweme.music.ui.MusicDetailActivity', 'com.ss.android.ugc.aweme.live.LivePlayActivity', 'com.ss.android.ugc.aweme.host.TikTokHostActivity', 'com.ss.android.ugc.aweme.profile.ui.I18nHeaderDetailActivity', 'com.bytedance.hybrid.spark.page.SparkActivity', 'com.ss.android.ugc.aweme.deeplink.AppLinkHandlerV2', 'com.ss.android.ugc.aweme.pns.universalpopup.core.ui.UniversalPopupActivity', 'com.ss.android.ugc.aweme.notification.UserListActivity', 'com.ss.android.ugc.aweme.following.ui.FollowRelationTabActivity', 'com.ss.android.ugc.aweme.deeplink.DeepLinkActivityV2', 'com.ss.android.ugc.aweme.prop.activity.StickerPropDetailActicity', 'com.ss.android.ugc.aweme.shortvideo.ui.VideoRecordNewActivity', 'com.ss.android.ugc.aweme.adaptation.saa.SAAActivity', 'com.ss.android.ugc.aweme.shortvideo.ui.VideoPublishActivity', 'com.ss.android.ugc.aweme.shortvideo.vechoosecover.ChooseCoverActivity', 'com.ss.android.ugc.aweme.nows.ui.NowsEditActivity', 'com.ss.android.ugc.aweme.ui.activity.PostModeDetailActivity', 'com.ss.android.ugc.aweme.setting.ui.SettingContainerActivity', 'com.ss.android.ugc.aweme.watch.history.core.WatchHistoryActivity', 'com.ss.android.ugc.aweme.crossplatform.activity.CrossPlatformActivity', 'com.ss.android.ugc.gamora.editorpro.anchor.EditorProAnchorActivity', 'com.ss.android.ugc.aweme.shortvideo.mvtemplate.choosemedia.MvChoosePhotoActivity', 'com.ss.android.ugc.aweme.journey.NewUserJourneyActivity', 'com.ss.android.ugc.aweme.account.login.v2.ui.SignUpOrLoginActivity', 'com.ss.android.ugc.aweme.relation.ffp.ui.FindFriendsPageActivity', 'com.ss.android.ugc.aweme.profile.ui.ProfileEditActivity', 'com.ss.android.ugc.aweme.bullet.BulletContainerActivity', 'com.ss.android.ugc.aweme.mix.videodetail.MixVideoDetailActivity', 'com.ss.android.ugc.aweme.image.ui.ImageEditActivity', 'com.zhihu.matisse.ui.MatisseActivity', 'com.zhihu.matisse.internal.ui.AlbumPreviewActivity', 'com.ss.android.ugc.aweme.profile.ui.CropActivity', 'com.ss.android.ugc.aweme.compliance.business.report.ReportWebPageDialogActivity', 'com.ss.android.ugc.aweme.ecommerce.base.osp.page.OrderSubmitActivity', 'com.ss.android.ugc.aweme.ecommerce.base.pdp.ui.PdpActivity', 'com.bytedance.lobby.internal.LobbyInvisibleActivity', 'com.facebook.FacebookActivity', 'com.ss.android.ugc.aweme.challenge.ui.ChallengeDetailActivity', 'com.bytedance.ies.ugc.aweme.commercialize.compliance.personalization.AdPersonalizationActivity', 'com.ss.android.ugc.aweme.account.login.auth.I18nSignUpActivityWithNoAnimation', 'com.ss.android.ugc.aweme.account.login.authorize.AuthorizeActivity', 'com.ss.android.ugc.aweme.account.login.auth.I18nSignUpActivity', 'com.ss.android.ugc.aweme.shortvideo.ui.VideoRecordPermissionActivity', 'com.ss.android.ugc.aweme.share.SystemShareActivity', 'com.ss.android.ugc.aweme.shortvideo.edit.VEVideoPublishEditActivity', 'com.ss.android.ugc.aweme.choosemusic.activity.ChooseMusicActivity', 'com.ss.android.ugc.aweme.tools.draft.DraftBoxActivity', 'com.ss.android.ugc.aweme.im.sdk.relations.ui.activity.RelationSelectActivity', 'com.ss.android.ugc.aweme.share.qrcode.UserQRCodeActivity', 'com.bytedance.lobby.instagram.InstagramAuthActivity', 'com.ss.android.ugc.aweme.search.pages.result.effectlist.core.ui.SearchEffectListActivity', 'com.facebook.CustomTabMainActivity', 'com.ss.android.ugc.aweme.feed.landscape.LandscapeFeedActivity', 'com.ss.android.ugc.aweme.setting.I18nSettingManageMyAccountActivity', 'com.ss.android.ugc.aweme.im.sdk.chatdetail.ui.activity.FriendChatDetailActivity', 'com.android.billingclient.api.ProxyBillingActivity', 'com.ss.android.ugc.aweme.livewallpaper.ui.LiveWallPaperPreviewActivity', 'com.ss.android.ugc.aweme.main.replace.OpenEditPageHandlerActivity', 'com.ss.android.ugc.aweme.i18n.musically.cut.AvatarChooseActivity', 'com.ss.android.ug ...

# %%
usage[(usage['id'] == 'p062') & (usage['date'] == '2023-07-26')]
# Out:
#           id                                  uuid            datetime  \
# 215010  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 04:03:08
# 215052  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 04:19:16
# 215894  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 04:33:26
# 215911  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 04:49:32
# 215917  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 05:03:39
# ...      ...                                   ...                 ...
# 227177  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:51:53
# 227180  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:53:19
# 227183  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:53:53
# 227186  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:57:00
# 227192  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:59:29
#
#                        eventType          time        date  \
# 215010  FOREGROUND_SERVICE_START  1.690372e+12  2023-07-26
# 215052  FOREGROUND_SERVICE_START  1.690372e+12  2023-07-26
# 215894  FOREGROUND_SERVICE_START  1.690372e+12  2023-07-26
# 215911  FOREGROUND_SERVICE_START  1.690372e+12  2023-07-26
# 215917  FOREGROUND_SERVICE_START  1.690372e+12  2023-07-26
# ...                          ...           ...         ...
# 227177  FOREGROUND_SERVICE_START  1.690415e+12  2023-07-26
# 227180  FOREGROUND_SERVICE_START  1.690415e+12  2023-07-26
# 227183  FOREGROUND_SERVICE_START  1.690415e+12  2023-07-26
# 227186  FOREGROUND_SERVICE_START  1.690415e+12  2023-07-26
# 227192  FOREGROUND_SERVICE_START  1.690415e+12  2023-07-26
#
#                                                 className   appName
# 215010  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 215052  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 215894  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 215911  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 215917  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# ...                                                   ...       ...
# 227177  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 227180  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 227183  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 227186  com.snap.location.livelocation.LiveLocationBou...  Snapchat
# 227192  com.snap.location.livelocation.LiveLocationBou...  Snapchat
#
# [3730 rows x 8 columns]

# %%
usage[(usage['id'] == 'p062') & (usage['date'] == '2023-07-26') & (usage['eventType'] == 'ACTIVITY_RESUMED')]
# Out:
#           id                                  uuid            datetime  \
# 216575  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 13:12:27
# 216580  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 13:13:05
# 216583  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 13:13:18
# 216586  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 13:13:22
# 216589  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-25 13:13:25
# ...      ...                                   ...                 ...
# 226991  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:17:34
# 227000  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:17:36
# 227076  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:34:26
# 227078  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:34:26
# 227083  p062  640b0635-3307-4326-ac1e-8606b117be01 2023-07-26 15:34:40
#
#                eventType          time        date  \
# 216575  ACTIVITY_RESUMED  1.690372e+12  2023-07-26
# 216580  ACTIVITY_RESUMED  1.690372e+12  2023-07-26
# 216583  ACTIVITY_RESUMED  1.690372e+12  2023-07-26
# 216586  ACTIVITY_RESUMED  1.690372e+12  2023-07-26
# 216589  ACTIVITY_RESUMED  1.690372e+12  2023-07-26
# ...                  ...           ...         ...
# 226991  ACTIVITY_RESUMED  1.690415e+12  2023-07-26
# 227000  ACTIVITY_RESUMED  1.690415e+12  2023-07-26
# 227076  ACTIVITY_RESUMED  1.690415e+12  2023-07-26
# 227078  ACTIVITY_RESUMED  1.690415e+12  2023-07-26
# 227083  ACTIVITY_RESUMED  1.690415e+12  2023-07-26
#
#                                                 className    appName
# 216575         com.ss.android.ugc.aweme.main.MainActivity     TikTok
# 216580  com.ss.android.ugc.aweme.search.pages.core.ui....     TikTok
# 216583  com.ss.android.ugc.aweme.detail.ui.DetailActivity     TikTok
# 216586  com.ss.android.ugc.aweme.search.pages.core.ui....     TikTok
# 216589         com.ss.android.ugc.aweme.main.MainActivity     TikTok
# ...                                                   ...        ...
# 226991                     com.snap.mushroom.MainActivity   Snapchat
# 227000                     com.snap.mushroom.MainActivity   Snapchat
# 227076            com.instagram.mainactivity.MainActivity  Instagram
# 227078                  com.instagram.modal.ModalActivity  Instagram
# 227083                     com.snap.mushroom.MainActivity   Snapchat
#
# [1017 rows x 8 columns]

# %%
ls_class = usage.groupby('appName')['className'].unique()
print(ls_class)
for _ in ls_class:
    print(_)
# Out:
# appName
# AppMinder    [com.example.drg2023.MainActivity, com.example...
# Instagram    [com.instagram.modal.ModalActivity, com.instag...
# Snapchat     [com.snap.mushroom.MainActivity, nan, com.snap...
# TikTok       [com.ss.android.ugc.aweme.main.MainActivity, c...
# Name: className, dtype: object
# ['com.example.drg2023.MainActivity'
#  'com.example.drg2023.AppUsageMonitorService'
#  'com.example.drg2023.TrackerService' nan
#  'com.example.drg2023.DialogActivity'
#  'com.android.launcher3.uioverrides.QuickstepLauncher']
# ['com.instagram.modal.ModalActivity'
#  'com.instagram.mainactivity.MainActivity'
#  'com.instagram.urlhandlers.clips.ClipsUrlHandlerActivity' nan
#  'com.instagram.modal.TransparentModalActivity'
#  'com.instagram.mainactivity.LauncherActivity'
#  'com.facebook.browser.lite.BrowserLiteInMainProcessBottomSheetActivity'
#  'androidx.work.impl.foreground.SystemForegroundService'
#  'com.instagram.url.UrlHandlerLauncherActivity'
#  'com.instagram.url.UrlHandlerActivity'
#  'com.instagram.pendingmedia.service.impl.PendingMediaNotificationService'
#  'com.instagram.urlhandlers.media.MediaExternalUrlHandlerActivity'
#  'com.instagram.creation.activity.MediaCaptureActivity'
#  'com.instagram.business.promote.activity.PromoteActivity'
#  'com.instagram.urlhandlers.clipsaudio.ClipsAudioUrlHandlerActivity'
#  'com.instagram.nux.activity.BloksSignedOutFragmentActivity'
#  'com.instagram.rtc.activity.RtcCallIntentHandlerActivity'
#  'com.instagram.rtc.activity.RtcCallActivity'
#  'com.instagram.rtc.service.OngoingCallServiceWithMic'
#  'com.instagram.tagging.activity.TaggingActivity'
#  'com.instagram.nux.activity.SignedOutFragmentActivity'
#  'com.instagram.nux.impl.dynamicflow.onboarding.OnboardingActivity'
#  'com.instagram.creation.photo.crop.AvatarCropActivity'
#  'com.instagram.urlhandlers.professionaldashboardexternal.ProfessionalDashboardExternalUrlHandlerActivity'
#  'com.instagram.urlhandlers.directpollmessage.DirectPollMessageUrlHandlerActivity'
#  'com.instagram.direct.share.handler.DirectExternalMediaShareActivity'
#  'com.instagram.business.activity.BusinessConversionActivity'
#  'com.facebook.FacebookActivity'
#  'com.instagram.share.handleractivity.StoryShareHandlerActivity'
#  'com.instagram.direct.share.handler.DirectShareHandlerActivity'
#  'com.instagram.urlhandlers.interappidentityswitch.InterAppIdentitySwitchUrlHandlerActivity'
#  'com.instagram.urlhandlers.managesavedlogin.ManageSavedLoginUrlHandlerActivity'
#  'com.instagram.modal.TransparentBackgroundModalActivity'
#  'com.instagram.simplewebview.SimpleWebViewActivity'
#  'com.instagram.share.handleractivity.MultiStoryShareHandlerActivity'
#  'com.instagram.urlhandlers.directgroupinvite.DirectGroupInviteHandlerActivity'
#  'com.instagram.urlhandlers.viewprofile.ViewProfileUrlHandlerActivity'
#  'com.instagram.share.handleractivity.ShareHandlerActivity'
#  'com.instagram.share.handleractivity.CustomStoryShareHandlerActivity'
#  'com.instagram.urlhandlers.genericsurvey.GenericSurveyUrlHandlerActivity'
#  'com.instagram.urlhandlers.igme.IgMeExternalUrlHandlerActivity'
#  'com.instagram.urlhandlers.openinexternalbrowser.OpenInExternalBrowserUrlHandlerActivity'
#  'com.instagram.leadads.activity.LeadAdsActivity'
#  'com.instagram.challenge.activity.ChallengeActivity'
#  'com.instagram.urlhandlers.fundraiserexternal.FundraiserExternalUrlHandlerActivity'
#  'com.instagram.inappbrowser.actions.BrowserActionActivity'
#  'com.instagram.urlhandlers.consentaction.ConsentActionUrlHandlerActivity'
#  'com.instagram.urlhandlers.attribution.AttributionUrlHandlerActivity'
#  'com.instagram.fxcal.browser.FxChromeCustomTabsActivity'
#  'com.instagram.mainactivity.MainActivivity'
#  'com.instagramdal.ModalActivity' 'com.i.modal.ModalActivity']
# ['com.snap.mushroom.MainActivity' nan
#  'com.snap.messaging.talk.InCallService'
#  'com.snap.media.export.MediaExportService'
#  'com.snap.talk.core.InCallService'
#  'com.snap.location.livelocation.LiveLocationBoundService'
#  'com.snap.identity.loginsignup.ui.LoginSignupActivity'
#  'androidx.work.impl.foreground.SystemForegroundService'
#  'com.snap.identity.ui.legal.LegalAgreementActivity'
#  'com.snap.talk.lockscreen.LockScreenActivity'
#  'com.android.billingclient.api.ProxyBillingActivity'
#  'com.jakewharton.processphoenix.ProcessPhoenix']
# ['com.ss.android.ugc.aweme.main.MainActivity'
#  'com.ss.android.ugc.aweme.search.pages.core.ui.activity.SearchResultActivity'
#  'com.ss.android.ugc.aweme.detail.ui.DetailActivity'
#  'com.ss.android.ugc.aweme.music.ui.MusicDetailActivity'
#  'com.ss.android.ugc.aweme.live.LivePlayActivity'
#  'com.ss.android.ugc.aweme.host.TikTokHostActivity'
#  'com.ss.android.ugc.aweme.profile.ui.I18nHeaderDetailActivity'
#  'com.bytedance.hybrid.spark.page.SparkActivity'
#  'com.ss.android.ugc.aweme.deeplink.AppLinkHandlerV2'
#  'com.ss.android.ugc.aweme.pns.universalpopup.core.ui.UniversalPopupActivity'
#  'com.ss.android.ugc.aweme.notification.UserListActivity'
#  'com.ss.android.ugc.aweme.following.ui.FollowRelationTabActivity' nan
#  'com.ss.android.ugc.aweme.deeplink.DeepLinkActivityV2'
#  'com.bytedance.android.livesdk.notificatoin.AudioLiveService'
#  'com.ss.android.ugc.aweme.prop.activity.StickerPropDetailActicity'
#  'com.ss.android.ugc.aweme.shortvideo.ui.VideoRecordNewActivity'
#  'com.ss.android.ugc.aweme.adaptation.saa.SAAActivity'
#  'com.ss.android.ugc.aweme.shortvideo.ui.VideoPublishActivity'
#  'com.ss.android.ugc.aweme.shortvideo.vechoosecover.ChooseCoverActivity'
#  'com.ss.android.ugc.aweme.nows.ui.NowsEditActivity'
#  'com.ss.android.ugc.aweme.ui.activity.PostModeDetailActivity'
#  'com.ss.android.ugc.aweme.setting.ui.SettingContainerActivity'
#  'com.ss.android.ugc.aweme.watch.history.core.WatchHistoryActivity'
#  'com.ss.android.ugc.aweme.crossplatform.activity.CrossPlatformActivity'
#  'com.ss.android.ugc.gamora.editorpro.anchor.EditorProAnchorActivity'
#  'com.ss.android.ugc.aweme.shortvideo.mvtemplate.choosemedia.MvChoosePhotoActivity'
#  'com.ss.android.ugc.aweme.journey.NewUserJourneyActivity'
#  'com.ss.android.ugc.aweme.account.login.v2.ui.SignUpOrLoginActivity'
#  'com.ss.android.ugc.aweme.relation.ffp.ui.FindFriendsPageActivity'
#  'com.ss.android.ugc.aweme.profile.ui.ProfileEditActivity'
#  'com.ss.android.ugc.aweme.scheduler.PublishService'
#  'com.ss.android.ugc.aweme.bullet.BulletContainerActivity'
#  'com.ss.android.ugc.aweme.mix.videodetail.MixVideoDetailActivity'
#  'com.ss.android.ugc.aweme.image.ui.ImageEditActivity'
#  'com.zhihu.matisse.ui.MatisseActivity'
#  'com.zhihu.matisse.internal.ui.AlbumPreviewActivity'
#  'com.ss.android.ugc.aweme.profile.ui.CropActivity'
#  'com.ss.android.ugc.aweme.compliance.business.report.ReportWebPageDialogActivity'
#  'com.ss.android.ugc.aweme.ecommerce.base.osp.page.OrderSubmitActivity'
#  'com.ss.android.ugc.aweme.ecommerce.base.pdp.ui.PdpActivity'
#  'com.bytedance.lobby.internal.LobbyInvisibleActivity'
#  'com.facebook.FacebookActivity'
#  'com.ss.android.ugc.aweme.challenge.ui.ChallengeDetailActivity'
#  'com.bytedance.ies.ugc.aweme.commercialize.compliance.personalization.AdPersonalizationActivity'
#  'com.ss.android.ugc.aweme.account.login.auth.I18nSignUpActivityWithNoAnimation'
#  'com.ss.android.ugc.aweme.account.login.authorize.AuthorizeActivity'
#  'com.ss.android.ugc.aweme.account.login.auth.I18nSignUpActivity'
#  'com.ss.android.ugc.aweme.shortvideo.ui.VideoRecordPermissionActivity'
#  'com.ss.android.ugc.aweme.share.SystemShareActivity'
#  'com.ss.android.ugc.aweme.shortvideo.edit.VEVideoPublishEditActivity'
#  'com.ss.android.ugc.aweme.choosemusic.activity.ChooseMusicActivity'
#  'com.ss.android.ugc.aweme.tools.draft.DraftBoxActivity'
#  'com.ss.android.ugc.aweme.im.sdk.relations.ui.activity.RelationSelectActivity'
#  'com.ss.android.ugc.aweme.share.qrcode.UserQRCodeActivity'
#  'com.bytedance.lobby.instagram.InstagramAuthActivity'
#  'com.ss.android.ugc.aweme.search.pages.result.effectlist.core.ui.SearchEffectListActivity'
#  'com.facebook.CustomTabMainActivity'
#  'com.ss.android.ugc.aweme.feed.landscape.LandscapeFeedActivity'
#  'com.ss.android.ugc.aweme.setting.I18nSettingManageMyAccountActivity'
#  'com.ss.android.ugc.aweme.im.sdk.chatdetail.ui.activity.FriendChatDetailActivity'
#  'com.android.billingclient.api.ProxyBillingActivity'
#  'com.androiinActivity'
#  'com.ss.android.ugc.aweme.livewallpaper.ui.LiveWallPaperPreviewActivity'
#  'com.ss.android.ugc.aweme.main.replace.OpenEditPageHandlerActivity'
#  'com.ss.android.ugc.aweme.i18n.musically.cut.AvatarChooseActivity'
#  'com.ss.android.ugc.aweme.i18n.musically.cut.AvatarCutActivity'
#  'com.ss.android.ugc.aweme.livewallpaper.ui.LocalLiveWallPaperActivity'
#  'com.ss.android.ugc.aweme.choosemusic.activity.MusicDetailListActivity'
#  'com.google.android.gms.auth.api.signin.internal.SignInHubActivity'
#  'com.android.launcher3.uioverrd.ugc.aweme.main.MainActivity'
#  'com.ss.android.ugc.aweme.live.LiveBroadcastActivity'
#  'com.ss.android.ugc.aweme.im.sdk.chatlist.feature.stranger.ui.MessageRequestsActivity'
#  'com.android.launcher3.uioverrides.QuickstepL.android.ugc.aweme.im.sdk.chatlist.feature.stranger.ui.MessageRequestsActivity'
#  'com.bytedance.hybrid.spark.page.Spaom.ss.android.ugc.aweme.main.MainActivity'
#  'com.android.launcher3.uioverrides.QuickstepLarkActivity'
#  'com.ss.android.ugc.aweme.ecommerce.base.review.gallery.ReviewGalleryActivity'
#  'com.ss.android.ugc.aweme.ecommerce.showcase.showcase.ShowcaseActivity'
#  'com.ss.android.ugc.aweme.ecommerce.showcase.store.StoreActivity'
#  'com.ss.android.ugc.aweme.relation.fp.ContactFriendsPage$$Activity'
#  'com.ss.android.ugc.aweme.notification.MusNotificationDetailActivity'
#  'com.ss.android.ugc.aweme.search.activity.SearchResultActivity'
#  'com.ss.android.ugc.aweme.notification.MusFollowRequestDetailActivity']

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 assert False
#
# AssertionError:

# %% [markdown]
# ### Frequency of Interaction with AppMinder

# %%
foreground_activities = df_usage_events[df_usage_events['eventType'] == 'ACTIVITY_RESUMED']

# %%
foreground_activities.groupby(['id', 'appName']).size().unstack(fill_value=0)

# %% [markdown]
# ### Frequency of Social Media Use

# %% [markdown]
# ### Duration of Social Media Use

# %% [markdown]
# ### Rate of Non-response to Appminder Notifications

# %%
df_notifications = df_notifications[df_notifications['appName'] == 'AppMinder']
df_usage_events = df_usage_events[df_usage_events['appName'] == 'AppMinder']

# %%
df_notifications.sample(5)

# %%
df_usage_events.sample(5)

# %% [markdown]
# ### Stop Social Media After AppMinder Notification/Opening

# %% [markdown]
# ### Social Media Duration w/ vs. w/o AppMinder Notification
